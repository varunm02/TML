# %% [markdown]
# My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **VARUN MORE**
#
# I am currently working as Intern in Cognizant as programmer analyst trainee

# %% [markdown]
# *I am interested in data science as it is emerging field for many job opportunities. Being an mechnaical engineer I have some knowledge of production and automation sector
# hence data science can evolve loopholes in this sector.*

# %% [markdown]
# ### My next cell will perform an execution of addition of two numbers

# %%
num1 = 22
num2 = 44
print (num1+num2)
# Out:
# 66

# %% [markdown]
# * Kia seltos
# * tata Nexon
# * BMW X3 series
#
# 1. Kia seltos
# 2. tata nexon
# 3. BMW X3 series
#
# ![alt text]("C:\Users\pramo\OneDrive\Desktop\labrador-retriever-1210559__340.jpg.crdownload")
#
# > This is the quoated parargraph>
